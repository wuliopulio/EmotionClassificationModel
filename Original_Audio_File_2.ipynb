# %%
import torch
import torch.nn as nn
import torch.optim as optim


from torch.utils.data import Dataset, Subset, DataLoader


import torchvision
from torchvision import transforms


import matplotlib.pyplot as plt
import numpy as np
import os
from PIL import Image
import librosa


dtype = torch.float

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("ejlok1/toronto-emotional-speech-set-tess")

print("Path to dataset files:", path)
# Out:
# Path to dataset files: /kaggle/input/toronto-emotional-speech-set-tess

# %%
from pathlib import Path
import pandas as pd
import os

base_dir = '/kaggle/input/toronto-emotional-speech-set-tess'

file_emotion = []
file_path = []
# ['angry' 'disgust' 'fear' 'happy' 'neutral' 'sad']
for root, dirs, files in os.walk(base_dir):
    for file in files:
        if file.endswith('.wav'):
            full_path = os.path.join(root, file)

            emotion = file.split('_')[-1].split('.')[0]
            emotion = emotion.lower()
            if "pleasant" in emotion or "surprise" in emotion:
                emotion = "happy"
            elif emotion == "neutral":
                emotion = "neutral"
            elif emotion == "sad":
                emotion = "sad"
            elif emotion == "angry":
                emotion = "angry"
            elif emotion == "disgust":
                emotion = "disgust"
            elif emotion == "fear":
                emotion = "fear"
            elif emotion == "happy":
                emotion = "happy"

            file_emotion.append(emotion)
            file_path.append(full_path)

tess_df = pd.DataFrame({
    'Emotion': file_emotion,
    'Path': file_path
})

print(f"Total TESS files found: {len(tess_df)}")
print(tess_df.head())
# Out:
# Total TESS files found: 5600
#   Emotion                                               Path
# 0    fear  /kaggle/input/toronto-emotional-speech-set-tes...
# 1    fear  /kaggle/input/toronto-emotional-speech-set-tes...
# 2    fear  /kaggle/input/toronto-emotional-speech-set-tes...
# 3    fear  /kaggle/input/toronto-emotional-speech-set-tes...
# 4    fear  /kaggle/input/toronto-emotional-speech-set-tes...

# %%
dtype = torch.float
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %%
STANDARD_EMOTIONS = {
    'neutral': 0,
    'happy': 1,
    'sad': 2,
    'angry': 3,
    'fear': 4,
    'disgust': 5,
}

class AudioDataset(Dataset):
  def __init__(self, df, sample_rate, n_mels, duration):
    super().__init__()


    self.df = df
    self.sample_rate = sample_rate # Target sample rate for audio loading
    self.n_mels = n_mels # Specific frequency ranges derived from the Mel scale, which is designed to mimic how humans perceive sound
    self.duration = duration # Duration audio clips are adjusted to
    self.max_len = sample_rate * duration # Max samples per audio clip


    self.labels_map = STANDARD_EMOTIONS
    self.idx_to_emotion = {v: k for k, v in STANDARD_EMOTIONS.items()}

    # Sorted list of class labels
    self.transform = transforms.Compose([
        transforms.ToTensor(),
        transforms.Resize((128,128))
    ])


  def __len__(self):
    return len(self.df) # Number of audio clips


  def __getitem__(self, idx):
    file_path = self.df.iloc[idx]['Path']
    emotion = self.df.iloc[idx]['Emotion'].lower()

    if 'surprise' in emotion:
        emotion = 'happy'
    elif 'fearful' in emotion:
        emotion = 'fear'
    elif 'ps' in emotion:
      emotion = "surprise"

    if emotion not in self.labels_map:
        emotion = 'happy'

    label = self.labels_map[emotion]

    y, sample_rate = librosa.load(file_path, sr=self.sample_rate)

    if len(y) < self.max_len:
        y = np.pad(y, (0, self.max_len - len(y)))
    else:
        y = y[:self.max_len]

    mel = librosa.feature.melspectrogram(y=y, sr=sample_rate, n_mels=self.n_mels)
    mel_db = librosa.power_to_db(mel, ref=np.max)
    mel_tensor = self.transform(mel_db)

    return mel_tensor, label

# %%
full_dataset = AudioDataset(tess_df, sample_rate=22050, n_mels=128, duration=3)

print(len(tess_df))
length = len(tess_df)

indices = np.arange(len(full_dataset))
np.random.shuffle(indices)

train_indices = indices[:int(0.8*len(indices))]
test_indices = indices[int(0.8*len(indices)):]


trainset = Subset(full_dataset, train_indices)
testset = Subset(full_dataset, test_indices)
# Out:
# 5600

# %%
import collections
print(collections.Counter(tess_df['Emotion']))
# Out:
# Counter({'fear': 800, 'angry': 800, 'disgust': 800, 'neutral': 800, 'sad': 800, 'ps': 800, 'happy': 800})

# %%
trainloader = DataLoader(trainset, batch_size=32, shuffle=True)
testloader = DataLoader(testset, batch_size=32)

# %%
print(trainset[2])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-3577284449.py in <cell line: 0>()
# ----> 1 print(trainset[2])
#
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataset.py in __getitem__(self, idx)
#     410         if isinstance(idx, list):
#     411             return self.dataset[[self.indices[i] for i in idx]]
# --> 412         return self.dataset[self.indices[idx]]
#     413
#     414     def __getitems__(self, indices: List[int]) -> List[_T_co]:
#
# /tmp/ipython-input-3582835182.py in __getitem__(self, idx)
#      50     label = self.labels_map[emotion]
#      51
# ---> 52     y, sample_rate = librosa.load(file_path, sr=self.sample_rate)
#      53
#      54     if len(y) < self.max_len:
#
# /usr/local/lib/python3.11/dist-packages/librosa/core/audio.py in load(path, sr, mono, offset, duration, dtype, res_type)
#     188     # Final cleanup for dtype and contiguity
#     189     if mono:
# --> 190         y = to_mono(y)
#     191
#     192     if sr is not None:
#
# /usr/local/lib/python3.11/dist-packages/librosa/core/audio.py in to_mono(y)
#     503     """
#     504     # Validate the buffer
# --> 505     util.valid_audio(y)
#     506
#     507     if y.ndim > 1:
#
# /usr/local/lib/python3.11/dist-packages/lazy_loader/__init__.py in __getattr__(name)
#      80         elif name in attr_to_modules:
#      81             submod_path = f"{package_name}.{attr_to_modules[name]}"
# ---> 82             submod = importlib.import_module(submod_path)
#      83             attr = getattr(submod, name)
#      84
#
# /usr/lib/python3.11/importlib/__init__.py in import_module(name, package)
#     124                 break
#     125             level += 1
# --> 126     return _bootstrap._gcd_import(name[level:], package, level)
#     127
#     128
#
# /usr/lib/python3.11/importlib/_bootstrap.py in _gcd_import(name, package, level)
#
# /usr/lib/python3.11/importlib/_bootstrap.py in _find_and_load(name, import_)
#
# /usr/lib/python3.11/importlib/_bootstrap.py in _find_and_load_unlocked(name, import_)
#
# /usr/lib/python3.11/importlib/_bootstrap.py in _load_unlocked(spec)
#
# /usr/lib/python3.11/importlib/_bootstrap_external.py in exec_module(self, module)
#
# /usr/lib/python3.11/importlib/_bootstrap.py in _call_with_frames_removed(f, *args, **kwds)
#
# /usr/local/lib/python3.11/dist-packages/librosa/util/utils.py in <module>
#    1050
#    1051
# -> 1052 @numba.guvectorize(
#    1053     [
#    1054         "void(int16[:], bool_[:])",
#
# /usr/local/lib/python3.11/dist-packages/numba/np/ufunc/decorators.py in wrap(func)
#     201         guvec = GUVectorize(func, signature, **kwargs)
#     202         for fty in ftylist:
# --> 203             guvec.add(fty)
#     204         if len(ftylist) > 0:
#     205             guvec.disable_compile()
#
# /usr/local/lib/python3.11/dist-packages/numba/np/ufunc/gufunc.py in add(self, fty)
#     135
#     136     def add(self, fty):
# --> 137         self.gufunc_builder.add(fty)
#     138
#     139     def build_ufunc(self):
#
# /usr/local/lib/python3.11/dist-packages/numba/np/ufunc/ufuncbuilder.py in add(self, sig)
#     255         else:
#     256             targetoptions = self.nb_func.targetoptions
# --> 257         cres, args, return_type = _compile_element_wise_function(
#     258             self.nb_func, targetoptions, sig)
#     259         sig = self._finalize_signature(cres, args, return_type)
#
# /usr/local/lib/python3.11/dist-packages/numba/np/ufunc/ufuncbuilder.py in _compile_element_wise_function(nb_func, targetoptions, sig)
#     173     # Do compilation
#     174     # Return CompileResult to test
# --> 175     cres = nb_func.compile(sig, **targetoptions)
#     176     args, return_type = sigutils.normalize_signature(sig)
#     177     return cres, args, return_type
#
# /usr/local/lib/python3.11/dist-packages/numba/np/ufunc/ufuncbuilder.py in compile(self, sig, locals, **targetoptions)
#     121         flags.enable_looplift = False
#     122
# --> 123         return self._compile_core(sig, flags, locals)
#     124
#     125     def _compile_core(self, sig, flags, locals):
#
# /usr/local/lib/python3.11/dist-packages/numba/np/ufunc/ufuncbuilder.py in _compile_core(self, sig, flags, locals)
#     154                     # Compile
#     155                     args, return_type = sigutils.normalize_signature(sig)
# --> 156                     cres = compiler.compile_extra(typingctx, targetctx,
#     157                                                   self.py_func, args=args,
#     158                                                   return_type=return_type,
#
# /usr/local/lib/python3.11/dist-packages/numba/core/compiler.py in compile_extra(typingctx, targetctx, func, args, return_type, flags, locals, library, pipeline_class)
#     742     pipeline = pipeline_class(typingctx, targetctx, library,
#     743                               args, return_type, flags, locals)
# --> 744     return pipeline.compile_extra(func)
#     745
#     746
#
# /usr/local/lib/python3.11/dist-packages/numba/core/compiler.py in compile_extra(self, func)
#     436         self.state.lifted = ()
#     437         self.state.lifted_from = None
# --> 438         return self._compile_bytecode()
#     439
#     440     def compile_ir(self, func_ir, lifted=(), lifted_from=None):
#
# /usr/local/lib/python3.11/dist-packages/numba/core/compiler.py in _compile_bytecode(self)
#     504         """
#     505         assert self.state.func_ir is None
# --> 506         return self._compile_core()
#     507
#     508     def _compile_ir(self):
#
# /usr/local/lib/python3.11/dist-packages/numba/core/compiler.py in _compile_core(self)
#     470                 res = None
#     471                 try:
# --> 472                     pm.run(self.state)
#     473                     if self.state.cr is not None:
#     474                         break
#
# /usr/local/lib/python3.11/dist-packages/numba/core/compiler_machinery.py in run(self, state)
#     354                 pass_inst = _pass_registry.get(pss).pass_inst
#     355                 if isinstance(pass_inst, CompilerPass):
# --> 356                     self._runPass(idx, pass_inst, state)
#     357                 else:
#     358                     raise BaseException("Legacy pass in use")
#
# /usr/local/lib/python3.11/dist-packages/numba/core/compiler_lock.py in _acquire_compile_lock(*args, **kwargs)
#      33         def _acquire_compile_lock(*args, **kwargs):
#      34             with self:
# ---> 35                 return func(*args, **kwargs)
#      36         return _acquire_compile_lock
#      37
#
# /usr/local/lib/python3.11/dist-packages/numba/core/compiler_machinery.py in _runPass(self, index, pss, internal_state)
#     309                 mutated |= check(pss.run_initialization, internal_state)
#     310             with SimpleTimer() as pass_time:
# --> 311                 mutated |= check(pss.run_pass, internal_state)
#     312             with SimpleTimer() as finalize_time:
#     313                 mutated |= check(pss.run_finalizer, internal_state)
#
# /usr/local/lib/python3.11/dist-packages/numba/core/compiler_machinery.py in check(func, compiler_state)
#     271
#     272         def check(func, compiler_state):
# --> 273             mangled = func(compiler_state)
#     274             if mangled not in (True, False):
#     275                 msg = ("CompilerPass implementations should return True/False. "
#
# /usr/local/lib/python3.11/dist-packages/numba/core/typed_passes.py in run_pass(self, state)
#     466                 lower = self.lowering_class(targetctx, library, fndesc, interp,
#     467                                             metadata=metadata)
# --> 468                 lower.lower()
#     469                 if not flags.no_cpython_wrapper:
#     470                     lower.create_cpython_wrapper(flags.release_gil)
#
# /usr/local/lib/python3.11/dist-packages/numba/core/lowering.py in lower(self)
#     185         if self.generator_info is None:
#     186             self.genlower = None
# --> 187             self.lower_normal_function(self.fndesc)
#     188         else:
#     189             self.genlower = self.GeneratorLower(self)
#
# /usr/local/lib/python3.11/dist-packages/numba/core/lowering.py in lower_normal_function(self, fndesc)
#     224         # Init argument values
#     225         self.extract_function_arguments()
# --> 226         entry_block_tail = self.lower_function_body()
#     227
#     228         # Close tail of entry block, do not emit debug metadata else the
#
# /usr/local/lib/python3.11/dist-packages/numba/core/lowering.py in lower_function_body(self)
#     254             self.builder.position_at_end(bb)
#     255             self.debug_print(f"# lower block: {offset}")
# --> 256             self.lower_block(block)
#     257         self.post_lower()
#     258         return entry_block_tail
#
# /usr/local/lib/python3.11/dist-packages/numba/core/lowering.py in lower_block(self, block)
#     268             with new_error_context('lowering "{inst}" at {loc}', inst=inst,
#     269                                    loc=self.loc, errcls_=defaulterrcls):
# --> 270                 self.lower_inst(inst)
#     271         self.post_block(block)
#     272
#
# /usr/local/lib/python3.11/dist-packages/numba/core/lowering.py in lower_inst(self, inst)
#     446         if isinstance(inst, ir.Assign):
#     447             ty = self.typeof(inst.target.name)
# --> 448             val = self.lower_assign(ty, inst)
#     449             argidx = None
#     450             # If this is a store from an arg, like x = arg.x then tell debuginfo
#
# /usr/local/lib/python3.11/dist-packages/numba/core/lowering.py in lower_assign(self, ty, inst)
#     658
#     659         elif isinstance(value, ir.Expr):
# --> 660             return self.lower_expr(ty, value)
#     661
#     662         elif isinstance(value, ir.Var):
#
# /usr/local/lib/python3.11/dist-packages/numba/core/lowering.py in lower_expr(self, resty, expr)
#    1194
#    1195         elif expr.op == 'call':
# -> 1196             res = self.lower_call(resty, expr)
#    1197             return res
#    1198
#
# /usr/local/lib/python3.11/dist-packages/numba/core/lowering.py in lower_call(self, resty, expr)
#     923
#     924         else:
# --> 925             res = self._lower_call_normal(fnty, expr, signature)
#     926
#     927         # If lowering the call returned None, interpret that as returning dummy
#
# /usr/local/lib/python3.11/dist-packages/numba/core/lowering.py in _lower_call_normal(self, fnty, expr, signature)
#    1165             argvals = [the_self] + list(argvals)
#    1166
# -> 1167         res = impl(self.builder, argvals, self.loc)
#    1168         return res
#    1169
#
# /usr/local/lib/python3.11/dist-packages/numba/core/base.py in __call__(self, builder, args, loc)
#    1188
#    1189     def __call__(self, builder, args, loc=None):
# -> 1190         res = self._imp(self._context, builder, self._sig, args, loc=loc)
#    1191         self._context.add_linking_libs(getattr(self, 'libs', ()))
#    1192         return res
#
# /usr/local/lib/python3.11/dist-packages/numba/core/base.py in wrapper(*args, **kwargs)
#    1218             def wrapper(*args, **kwargs):
#    1219                 kwargs.pop('loc')     # drop unused loc
# -> 1220                 return fn(*args, **kwargs)
#    1221
#    1222             # Copy the following attributes from the wrapped.
#
# /usr/local/lib/python3.11/dist-packages/numba/stencils/stencil.py in __call__(self, context, builder, sig, args)
#      28
#      29     def __call__(self, context, builder, sig, args):
# ---> 30         cres = self.stencilFunc.compile_for_argtys(sig.args, {},
#      31                     sig.return_type, None)
#      32         res = context.call_internal(builder, cres.fndesc, sig, args)
#
# /usr/local/lib/python3.11/dist-packages/numba/stencils/stencil.py in compile_for_argtys(self, argtys, kwtys, return_type, sigret)
#     366         # look in the type cache to find if result array is passed
#     367         (_, result, typemap, calltypes) = self._type_cache[argtys]
# --> 368         new_func = self._stencil_wrapper(result, sigret, return_type,
#     369                                          typemap, calltypes, *argtys)
#     370         return new_func
#
# /usr/local/lib/python3.11/dist-packages/numba/stencils/stencil.py in _stencil_wrapper(self, result, sigret, return_type, typemap, calltypes, *args)
#     754         # body in it.
#     755         ir_utils.fixup_var_define_in_scope(stencil_ir.blocks)
# --> 756         new_func = compiler.compile_ir(
#     757             self._typingctx,
#     758             self._targetctx,
#
# /usr/local/lib/python3.11/dist-packages/numba/core/compiler.py in compile_ir(typingctx, targetctx, func_ir, args, return_type, flags, locals, lifted, lifted_from, is_lifted_loop, library, pipeline_class)
#     805         pipeline = pipeline_class(typingctx, targetctx, library,
#     806                                   args, return_type, flags, locals)
# --> 807         return pipeline.compile_ir(func_ir=func_ir, lifted=lifted,
#     808                                    lifted_from=lifted_from)
#     809
#
# /usr/local/lib/python3.11/dist-packages/numba/core/compiler.py in compile_ir(self, func_ir, lifted, lifted_from)
#     446
#     447         FixupArgs().run_pass(self.state)
# --> 448         return self._compile_ir()
#     449
#     450     def define_pipelines(self):
#
# /usr/local/lib/python3.11/dist-packages/numba/core/compiler.py in _compile_ir(self)
#     511         """
#     512         assert self.state.func_ir is not None
# --> 513         return self._compile_core()
#     514
#     515
#
# /usr/local/lib/python3.11/dist-packages/numba/core/compiler.py in _compile_core(self)
#     470                 res = None
#     471                 try:
# --> 472                     pm.run(self.state)
#     473                     if self.state.cr is not None:
#     474                         break
#
# /usr/local/lib/python3.11/dist-packages/numba/core/compiler_machinery.py in run(self, state)
#     354                 pass_inst = _pass_registry.get(pss).pass_inst
#     355                 if isinstance(pass_inst, CompilerPass):
# --> 356                     self._runPass(idx, pass_inst, state)
#     357                 else:
#     358                     raise BaseException("Legacy pass in use")
#
# /usr/local/lib/python3.11/dist-packages/numba/core/compiler_lock.py in _acquire_compile_lock(*args, **kwargs)
#      33         def _acquire_compile_lock(*args, **kwargs):
#      34             with self:
# ---> 35                 return func(*args, **kwargs)
#      36         return _acquire_compile_lock
#      37
#
# /usr/local/lib/python3.11/dist-packages/numba/core/compiler_machinery.py in _runPass(self, index, pss, internal_state)
#     309                 mutated |= check(pss.run_initialization, internal_state)
#     310             with SimpleTimer() as pass_time:
# --> 311                 mutated |= check(pss.run_pass, internal_state)
#     312             with SimpleTimer() as finalize_time:
#     313                 mutated |= check(pss.run_finalizer, internal_state)
#
# /usr/local/lib/python3.11/dist-packages/numba/core/compiler_machinery.py in check(func, compiler_state)
#     271
#     272         def check(func, compiler_state):
# --> 273             mangled = func(compiler_state)
#     274             if mangled not in (True, False):
#     275                 msg = ("CompilerPass implementations should return True/False. "
#
# /usr/local/lib/python3.11/dist-packages/numba/core/untyped_passes.py in run_pass(self, state)
#    1761
#    1762     def run_pass(self, state):
# -> 1763         state.func_ir = reconstruct_ssa(state.func_ir)
#    1764         self._patch_locals(state)
#    1765
#
# /usr/local/lib/python3.11/dist-packages/numba/core/ssa.py in reconstruct_ssa(func_ir)
#      30     Produces minimal SSA using Choi et al algorithm.
#      31     """
# ---> 32     func_ir.blocks = _run_ssa(func_ir.blocks)
#      33
#      34     return func_ir
#
# /usr/local/lib/python3.11/dist-packages/numba/core/ssa.py in _run_ssa(blocks)
#      56     df_plus = _iterated_domfronts(cfg)
#      57     # Find SSA violators
# ---> 58     violators = _find_defs_violators(blocks, cfg)
#      59     # Make cache for .list_vars()
#      60     cache_list_vars = _CacheListVars()
#
# /usr/local/lib/python3.11/dist-packages/numba/core/ssa.py in _find_defs_violators(blocks, cfg)
#     155     states = dict(defs=defs, uses=uses)
#     156     _run_block_analysis(blocks, states, _GatherDefsHandler())
# --> 157     _logger.debug("defs %s", pformat(defs))
#     158     # Gather violators by number of definitions.
#     159     # The violators are added by the order that they are seen and the algorithm
#
# /usr/lib/python3.11/pprint.py in pformat(object, indent, width, depth, compact, sort_dicts, underscore_numbers)
#      60     return PrettyPrinter(indent=indent, width=width, depth=depth,
#      61                          compact=compact, sort_dicts=sort_dicts,
# ---> 62                          underscore_numbers=underscore_numbers).pformat(object)
#      63
#      64 def pp(object, *args, sort_dicts=False, **kwargs):
#
# /usr/lib/python3.11/pprint.py in pformat(self, object)
#     159     def pformat(self, object):
#     160         sio = _StringIO()
# --> 161         self._format(object, sio, 0, 0, {}, 0)
#     162         return sio.getvalue()
#     163
#
# /usr/lib/python3.11/pprint.py in _format(self, object, stream, indent, allowance, context, level)
#     182             if p is not None:
#     183                 context[objid] = 1
# --> 184                 p(self, object, stream, indent, allowance, context, level + 1)
#     185                 del context[objid]
#     186                 return
#
# /usr/lib/python3.11/pprint.py in _pprint_default_dict(self, object, stream, indent, allowance, context, level)
#     479         indent += len(cls.__name__) + 1
#     480         stream.write('%s(%s,\n%s' % (cls.__name__, rdf, ' ' * indent))
# --> 481         self._pprint_dict(object, stream, indent, allowance + 1, context, level)
#     482         stream.write(')')
#     483
#
# /usr/lib/python3.11/pprint.py in _pprint_dict(self, object, stream, indent, allowance, context, level)
#     218             else:
#     219                 items = object.items()
# --> 220             self._format_dict_items(items, stream, indent, allowance + 1,
#     221                                     context, level)
#     222         write('}')
#
# /usr/lib/python3.11/pprint.py in _format_dict_items(self, items, stream, indent, allowance, context, level)
#     389             write(rep)
#     390             write(': ')
# --> 391             self._format(ent, stream, indent + len(rep) + 2,
#     392                          allowance if last else 1,
#     393                          context, level)
#
# /usr/lib/python3.11/pprint.py in _format(self, object, stream, indent, allowance, context, level)
#     176             self._readable = False
#     177             return
# --> 178         rep = self._repr(object, context, level)
#     179         max_width = self._width - indent - allowance
#     180         if len(rep) > max_width:
#
# /usr/lib/python3.11/pprint.py in _repr(self, object, context, level)
#     456
#     457     def _repr(self, object, context, level):
# --> 458         repr, readable, recursive = self.format(object, context.copy(),
#     459                                                 self._depth, level)
#     460         if not readable:
#
# /usr/lib/python3.11/pprint.py in format(self, object, context, maxlevels, level)
#     469         and whether the object represents a recursive construct.
#     470         """
# --> 471         return self._safe_repr(object, context, maxlevels, level)
#     472
#     473     def _pprint_default_dict(self, object, stream, indent, allowance, context, level):
#
# /usr/lib/python3.11/pprint.py in _safe_repr(self, object, context, maxlevels, level)
#     622                 orepr, oreadable, orecur = self.format(
#     623                     o, context, maxlevels, level)
# --> 624                 append(orepr)
#     625                 if not oreadable:
#     626                     readable = False
#
# KeyboardInterrupt:

# %%
data1 = next(iter(trainloader))

print(data1)
# Out:
# [tensor([[[[-46.1256, -36.8580, -35.4275,  ..., -80.0000, -80.0000, -80.0000],
#           [-55.5184, -54.9952, -55.3321,  ..., -80.0000, -80.0000, -80.0000],
#           [-73.1595, -70.5577, -67.3916,  ..., -80.0000, -80.0000, -80.0000],
#           ...,
#           [-80.0000, -79.5802, -68.4582,  ..., -80.0000, -80.0000, -80.0000],
#           [-80.0000, -79.6714, -70.7532,  ..., -80.0000, -80.0000, -80.0000],
#           [-80.0000, -79.9785, -78.9531,  ..., -80.0000, -80.0000, -80.0000]]],
#
#
#         [[[-42.6343, -31.0210, -29.0362,  ..., -80.0000, -80.0000, -80.0000],
#           [-52.5477, -46.5076, -43.7960,  ..., -80.0000, -80.0000, -80.0000],
#           [-53.0014, -50.9178, -56.1630,  ..., -80.0000, -80.0000, -80.0000],
#           ...,
#           [-79.7728, -69.5116, -56.5736,  ..., -80.0000, -80.0000, -80.0000],
#           [-79.8574, -73.2651, -61.0827,  ..., -80.0000, -80.0000, -80.0000],
#           [-80.0000, -79.6107, -69.3386,  ..., -80.0000, -80.0000, -80.0000]]],
#
#
#         [[[-49.7623, -46.0744, -38.8970,  ..., -80.0000, -80.0000, -80.0000],
#           [-46.2710, -46.0014, -43.6094,  ..., -80.0000, -80.0000, -80.0000],
#           [-50.1565, -47.3785, -41.6869,  ..., -80.0000, -80.0000, -80.0000],
#           ...,
#           [-72.9580, -57.4513, -46.0309,  ..., -80.0000, -80.0000, -80.0000],
#           [-74.2772, -61.2118, -50.5644,  ..., -80.0000, -80.0000, -80.0000],
#           [-79.8358, -72.3245, -60.5004,  ..., -80.0000, -80.0000, -80.0000]]],
#
#
#         ...,
#
#
#         [[[-53.0051, -51.1919, -47.7156,  ..., -80.0000, -80.0000, -80.0000],
#           [-54.3010, -53.2439, -53.8683,  ..., -80.0000, -80.0000, -80.0000],
#           [-55.9695, -52.8840, -53.5575,  ..., -80.0000, -80.0000, -80.0000],
#           ...,
#           [-72.3121, -54.5348, -45.0443,  ..., -80.0000, -80.0000, -80.0000],
#           [-74.7704, -55.5514, -43.0821,  ..., -80.0000, -80.0000, -80.0000],
#           [-79.6357, -63.4796, -50.7250,  ..., -80.0000, -80.0000, -80.0000]]],
#
#
#         [[[-50.0164, -37.7462, -27.1448,  ..., -80.0000, -80.0000, -80.0000],
#           [-58.1240, -53.0796, -50.7049,  ..., -80.0000, -80.0000, -80.0000],
#           [-70.7589, -70.7471, -73.6512,  ..., -80.0000, -80.0000, -80.0000],
#           ...,
#           [-80.0000, -79.7066, -71.7288,  ..., -80.0000, -80.0000, -80.0000],
#           [-80.0000, -79.8743, -76.1655,  ..., -80.0000, -80.0000, -80.0000],
#           [-80.0000, -80.0000, -79.7755,  ..., -80.0000, -80.0000, -80.0000]]],
#
#
#         [[[-44.2518, -40.5942, -38.2716,  ..., -80.0000, -80.0000, -80.0000],
#           [-52.6125, -45.7823, -42.4149,  ..., -80.0000, -80.0000, -80.0000],
#           [-54.0842, -45.6121, -43.4624,  ..., -80.0000, -80.0000, -80.0000],
#           ...,
#           [-75.1133, -60.5794, -47.8606,  ..., -80.0000, -80.0000, -80.0000],
#           [-76.1774, -61.9969, -51.4743,  ..., -80.0000, -80.0000, -80.0000],
#           [-79.8792, -74.3508, -65.2582,  ..., -80.0000, -80.0000, -80.0000]]]]), tensor([3, 2, 2, 5, 0, 2, 1, 1, 0, 5, 1, 0, 3, 1, 5, 1, 5, 3, 2, 4, 3, 5, 3, 1,
#         1, 5, 1, 1, 5, 4, 3, 0])]

# %%
class CNN(nn.Module):
  def __init__(self):
      super(CNN, self).__init__()

      self.conv1 = nn.Conv2d(in_channels=1, out_channels=16, kernel_size=3, padding=1)
      self.bn1 = nn.BatchNorm2d(16)
      self.pool1 = nn.MaxPool2d(kernel_size=2, stride=2)  # 64x64x16

      self.conv2 = nn.Conv2d(16, 32, kernel_size=3, padding=1)
      self.bn2 = nn.BatchNorm2d(32)
      self.pool2 = nn.MaxPool2d(kernel_size=2, stride=2)  # 32x32x32

      self.conv3 = nn.Conv2d(32, 64, kernel_size=3, padding=1)
      self.bn3 = nn.BatchNorm2d(64)
      self.pool3 = nn.MaxPool2d(kernel_size=2, stride=2)  # 16x16x64

      self.conv4 = nn.Conv2d(64, 128, kernel_size=3, padding=1)
      self.bn4 = nn.BatchNorm2d(128)
      self.pool4 = nn.MaxPool2d(kernel_size=2, stride=2)  # 8x8x128

      self.flattened_size = 128 * 8 * 8

      self.fc1 = nn.Linear(self.flattened_size, 256)
      self.dropout = nn.Dropout(0.5)

      self.fc2 = nn.Linear(256, 128)

      self.fc3 = nn.Linear(128, len(STANDARD_EMOTIONS))
  def forward(self, x):


    x = self.pool1(torch.relu(self.bn1(self.conv1(x))))
    x = self.pool2(torch.relu(self.bn2(self.conv2(x))))
    x = self.pool3(torch.relu(self.bn3(self.conv3(x))))
    x = self.pool4(torch.relu(self.bn4(self.conv4(x))))


    x = x.view(x.size(0), -1)


    x = torch.relu(self.fc1(x))
    x = self.dropout(x)
    x = torch.relu(self.fc2(x))
    x = self.fc3(x)


    return x

# %%
import torchvision.models as models

# Mount drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# /tmp/ipython-input-686611631.py in <cell line: 0>()
#       3 # Mount drive
#       4 from google.colab import drive
# ----> 5 drive.mount('/content/drive')
#
# /usr/local/lib/python3.11/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#      98 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#      99   """Mount your Google Drive at the specified mountpoint path."""
# --> 100   return _mount(
#     101       mountpoint,
#     102       force_remount=force_remount,
#
# /usr/local/lib/python3.11/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     135   )
#     136   if ephemeral:
# --> 137     _message.blocking_request(
#     138         'request_auth',
#     139         request={'authType': 'dfs_ephemeral'},
#
# /usr/local/lib/python3.11/dist-packages/google/colab/_message.py in blocking_request(request_type, request, timeout_sec, parent)
#     174       request_type, request, parent=parent, expect_reply=True
#     175   )
# --> 176   return read_reply_from_input(request_id, timeout_sec)
#
# /usr/local/lib/python3.11/dist-packages/google/colab/_message.py in read_reply_from_input(message_id, timeout_sec)
#     101     ):
#     102       if 'error' in reply:
# --> 103         raise MessageError(reply['error'])
#     104       return reply.get('data', None)
#     105
#
# MessageError: Error: credential propagation was unsuccessful

# %%
# Correct full path
model_path = '/content/drive/MyDrive/Emotion Classifier CNN/Models/New_Audio_attempt2_v2.pth'

# Load weights
model = CNN().to(device)
model.load_state_dict(torch.load(model_path, map_location=device))
# Out:
# <All keys matched successfully>

# %%
for param in model.conv1.parameters():
    param.requires_grad = False
for param in model.conv2.parameters():
    param.requires_grad = False

# %%
from tqdm import tqdm

optimizer = torch.optim.Adam(model.parameters(), lr = 0.001)
num_epochs = 8
batch_size = 16
loss_hist = []


criterion = nn.CrossEntropyLoss()


for epoch in range(num_epochs):
  correct = 0
  running_loss = 0
  total = 0
  for batch in tqdm(trainloader, desc=f"Epoch {epoch+1}/{num_epochs}", leave=True):

    inputs, labels = batch
    inputs = inputs.to(device)
    labels = labels.to(device)


    optimizer.zero_grad()


    outputs = model.forward(inputs)
    loss = criterion(outputs, labels)


    loss.backward()


    optimizer.step()
    running_loss += loss.item()

    loss_hist.append(loss.item())
  print(f"Loss {running_loss}")


  print(f"Epoch: {epoch+1}/{num_epochs} complete")
# Out:
# Epoch 1/8: 100%|██████████| 140/140 [01:25<00:00,  1.65it/s]
# Loss 24.900668470188975
# Epoch: 1/8 complete
# Epoch 2/8: 100%|██████████| 140/140 [01:02<00:00,  2.25it/s]
# Loss 12.179134187754244
# Epoch: 2/8 complete
# Epoch 3/8: 100%|██████████| 140/140 [01:03<00:00,  2.19it/s]
# Loss 9.620848990045488
# Epoch: 3/8 complete
# Epoch 4/8: 100%|██████████| 140/140 [01:02<00:00,  2.25it/s]
# Loss 8.549938738869969
# Epoch: 4/8 complete
# Epoch 5/8: 100%|██████████| 140/140 [01:02<00:00,  2.24it/s]
# Loss 8.092433320562122
# Epoch: 5/8 complete
# Epoch 6/8: 100%|██████████| 140/140 [01:03<00:00,  2.21it/s]
# Loss 8.50656909722602
# Epoch: 6/8 complete
# Epoch 7/8: 100%|██████████| 140/140 [01:01<00:00,  2.27it/s]
# Loss 8.033768348337617
# Epoch: 7/8 complete
# Epoch 8/8: 100%|██████████| 140/140 [01:03<00:00,  2.21it/s]
# Loss 7.281538487644866
# Epoch: 8/8 complete

# %%
def test_model(model, dataloader):
  correct = 0.0
  total = 0.0
  loss = 0.0
  criterion = nn.CrossEntropyLoss()
  with torch.no_grad():
    for image, label in dataloader:
      image = image.to(device)
      label = label.to(device)
      outputs = model(image)
      _, predictions = torch.max(outputs, 1)


      loss += criterion(outputs, label).item()


      total += label.size(0)
      correct += (predictions == label).sum().item()


  return (100*correct/total), (loss/len(dataloader))

# %%
test_model(model, testloader)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-953127282.py in <cell line: 0>()
# ----> 1 test_model(model, testloader)
#
# NameError: name 'model' is not defined

# %%
save_to = os.path.join('drive', 'MyDrive', 'Emotion Classifier CNN', 'Models', "New_Audio_attempt2_v3.pth")
os.makedirs(os.path.dirname(save_to), exist_ok=True)
torch.save(model.state_dict(), save_to)

# %%
import torchvision.models as models

# Mount drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Correct full path
model_path = '/content/drive/MyDrive/Emotion Classifier CNN/Models/New_Audio_attempt2_v3.pth'

# Load weights
model = CNN().to(device)
model.load_state_dict(torch.load(model_path, map_location=device))
# Out:
# <All keys matched successfully>

# %%
test_model(model, testloader)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-953127282.py in <cell line: 0>()
# ----> 1 test_model(model, testloader)
#
# NameError: name 'test_model' is not defined

# %%
def predict_emotion(audio_path, model, device):
    # Preprocess exactly like training
    sample_rate = 22050
    duration = 3
    n_mels = 128

    y, sr = librosa.load(audio_path, sr=sample_rate)
    y = y[:sample_rate*duration] if len(y) > sample_rate*duration else np.pad(y, (0, sample_rate*duration - len(y)))

    mel = librosa.feature.melspectrogram(y=y, sr=sr, n_mels=n_mels)
    mel_db = librosa.power_to_db(mel, ref=np.max)

    tensor = transforms.Compose([
        transforms.ToTensor(),
        transforms.Resize((128,128))
    ])(mel_db).unsqueeze(0).to(device)

    # Predict
    model.eval()
    with torch.no_grad():
        output = model(tensor)
        probs = torch.softmax(output, dim=1)
        conf, pred = torch.max(probs, 1)

    return pred.item(), conf.item(), probs.squeeze().tolist()

# Usage
class_idx, confidence, all_probs = predict_emotion('/content/drive/MyDrive/Emotion Classifier CNN/Audio/Joy.m4a', model, device)
print(f"Predicted: {class_idx} ({full_dataset.idx_to_emotion[class_idx]})")
print(f"Confidence: {confidence:.2%}")
for i, prob in enumerate(all_probs):
    print(f"{i}: {prob:.2%} {full_dataset.idx_to_emotion[i]}")
# Out:
# /tmp/ipython-input-4219925613.py:7: UserWarning: PySoundFile failed. Trying audioread instead.
#   y, sr = librosa.load(audio_path, sr=sample_rate)
# /usr/local/lib/python3.11/dist-packages/librosa/core/audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# Predicted: 1 (happy)
# Confidence: 95.78%
# 0: 0.00% neutral
# 1: 95.78% happy
# 2: 0.00% sad
# 3: 0.00% angry
# 4: 4.22% fear
# 5: 0.00% disgust
